# %% [markdown]
# This code combines the two different flowline datasets into one. One only had end points of an flowline and the other had the entire flowline. We combined them using a spatial join and asserted that the operator name is the same, with a max 25 meter buffer.

# %% [markdown]
# ## Setup

# %%
import os
import pandas as pd
import geopandas as gpd
import shapely
from shapely.geometry import Point, Polygon, MultiLineString, LineString,MultiPolygon, MultiPoint
from shapely.ops import nearest_points
os.chdir('/Users/ichittumuri/Documents/Github/SPE_Journal_Risk_Analysis_of_Flowlines/Data')
pd.options.display.max_columns = None

# %%
# Load Data
flowlines_gdf = gpd.read_file('flowlines.geojson')
crudeoil_gdf = gpd.read_file('crudeoil_offlocation.geojson')

# %%
# Check size
print(flowlines_gdf.shape)
print(crudeoil_gdf.shape)
# Out:
# (21253, 20)
# (259979, 8)

# %%
flowlines_gdf.head(2)
# Out:
#    LOCATION_ID  FLOWLINEID  STARTLOCATIONID  FLOWLINEACTION ENTIRELINEREMOVED  \
# 0     470443.0    470446.0              NaN            None              None
# 1     470443.0    470445.0         319521.0  Out of Service              True
#
#                                    ACTIONDESCRIPTION            RECEIVE_DATE  \
# 0  The flowline serving the Emerson 3-29J (05-123... 2023-10-24 08:33:49.223
# 1  The flowline (12311399_FL) servicing the Emers... 2023-10-24 08:33:49.223
#
#    OPERATOR_NUM                                       COMPANY_NAME  \
# 0         10633  CRESTONE PEAK RESOURCES OPERATING LLC         ...
# 1         10633  CRESTONE PEAK RESOURCES OPERATING LLC         ...
#
#             LOCATIONTYPE     ENDLAT     ENDLONG   STARTLAT   STARTLONG  \
# 0  Production Facilities  40.109444 -104.909686  40.105743 -104.909860
# 1  Production Facilities  40.109441 -104.909670  40.112203 -104.909862
#
#    PIPEMATERIAL   BEDDINGMATERIAL TYPEOFFLUIDTRANS  MAXOPPRESSURE  \
# 0  Carbon Steel  Native Materials       Multiphase          325.0
# 1  Carbon Steel  Native Materials       Multiphase          250.0
#
#   CONSTRUCTDATE                                           geometry
# 0    1983-11-09  LINESTRING (507682.442 4439497.658, 507696.855...
# 1    1983-12-07  LINESTRING (507681.545 4440214.668, 507698.219...

# %%
print(flowlines_gdf.geometry.iloc[1])
# Out:
# LINESTRING (507681.5449516433 4440214.668072899, 507698.2185429156 4439908.123743576)

# %%
crudeoil_gdf.head(5)
# Out:
#                           Operator       Fluid      Material  Diam_in  \
# 0  EVERGREEN NATURAL RESOURCES LLC         Gas         polly      4.0
# 1                 NOBLE ENERGY INC  Multiphase  Carbon Steel      3.0
# 2                   PDC ENERGY INC        None          None      NaN
# 3                 NOBLE ENERGY INC         Gas  Carbon Steel      3.0
# 4                 NOBLE ENERGY INC  Multiphase  Carbon Steel      3.0
#
#                         Status  Length_ft  SHAPE_Length  \
# 0                       Active    2277.71    693.972162
# 1                    Abandoned     651.58    198.525215
# 2  Partial Removed see comment    1902.59    579.687012
# 3                       Active     205.62     62.649840
# 4                       Active    2069.90    630.658768
#
#                                             geometry
# 0  MULTILINESTRING ((524642.67 4117088.796, 52463...
# 1  MULTILINESTRING ((527997.281 4463899.92, 52817...
# 2  MULTILINESTRING ((537519.211 4475984.687, 5375...
# 3  MULTILINESTRING ((544793.476 4489156.672, 5447...
# 4  MULTILINESTRING ((526448.455 4461830.702, 5258...

# %%
shapely.get_num_coordinates(crudeoil_gdf.geometry)
# Out:
# 0         46
# 1          2
# 2         26
# 3          2
# 4          2
#           ..
# 259974     5
# 259975    23
# 259976     2
# 259977    27
# 259978    15
# Name: geometry, Length: 259979, dtype: int32

# %%
print(crudeoil_gdf.geometry.iloc[1])
# Out:
# MULTILINESTRING ((527997.2812999999 4463899.920399999, 528172.7903000005 4463992.704299999))

# %%
# Check if CRS is the same for both files
if flowlines_gdf.crs != crudeoil_gdf.crs:
    flowlines_gdf = flowlines_gdf.to_crs(crudeoil_gdf.crs)

# %%
clean_crudeoil_gdf = crudeoil_gdf.dropna()
clean_crudeoil_gdf.shape
# Out:
# (138943, 8)

# %% [markdown]
# ## Match with Buffer
# find spatial match with/ buffer, update geometry

# %% [markdown]
# #### Test

# %%
from shapely.geometry import LineString

line1 = LineString([(0, 0), (1, 1)])
line2 = LineString([(0.5, 0.5), (2, 2)])
line3 = LineString([(1, 1), (1, 2)])

print(line1.intersects(line2))   
print(line1.intersects(line3))   
print(line2.intersects(line3))
# Out:
# True
# True
# True

# %% [markdown]
# Find matches
#
# If you have more time, try these different methods to get more data
# - do a scipy.spatial.KDTree.query to lessen the time it takes to search for a match

# %%
# Initialize an empty list to store matched data
matched_flowlines = []

max_buffer_distance = 25  # Maximum buffer distance in meters
buffer_increment = 0.5     # Buffer increment in meters

# Create spatial index for the crude oil geometries
oil_sindex = clean_crudeoil_gdf.sindex

for index, flowline in flowlines_gdf.iterrows():
    # Check for missing geometry and skip if necessary
    if flowline.geometry is None:
        print(f"Missing geometry for flowline at index {index}. Skipping...")
        continue

    # Extract the two end points of the flowline and create a new LineString
    coords = list(flowline.geometry.coords)
    endpoint_linestring = LineString([coords[0], coords[-1]])

    match_found = False
    buffer_distance = 0  # Start with no buffer

    # First, attempt to find a match without buffering
    possible_matches_index = list(oil_sindex.intersection(endpoint_linestring.bounds))
    possible_matches = clean_crudeoil_gdf.iloc[possible_matches_index]

    for _, crudeoil_line in possible_matches.iterrows():
        if endpoint_linestring.intersects(crudeoil_line.geometry):
            if flowline['COMPANY_NAME'].strip().lower() == crudeoil_line['Operator'].strip().lower():
                print(f"Immediate company match found for flowline at index {index} without buffering.")
                match_found = True
                break

    # If no immediate match, begin buffering
    if not match_found:
        while buffer_distance <= max_buffer_distance:
            buffered_endpoint_linestring = endpoint_linestring.buffer(buffer_distance)
            possible_matches_index = list(oil_sindex.intersection(buffered_endpoint_linestring.bounds))
            possible_matches = clean_crudeoil_gdf.iloc[possible_matches_index]

            for _, crudeoil_line in possible_matches.iterrows():
                if buffered_endpoint_linestring.intersects(crudeoil_line.geometry):
                    if flowline['COMPANY_NAME'].strip().lower() == crudeoil_line['Operator'].strip().lower():
                        print(f"Company match found for flowline at index {index} with buffer distance of {buffer_distance} meters.")
                        match_found = True
                        break

            if match_found:
                break
            buffer_distance += buffer_increment  # Increase the buffer distance

        # If no match was found and max buffer was reached
        if not match_found and buffer_distance > max_buffer_distance:
            print(f"No company match found for flowline at index {index} even after expanding buffer to {max_buffer_distance} meters.")

    # If a match is found, update the flowline with the crude oil line's attributes and geometry
    if match_found:
        updated_flowline = flowline.copy()
        updated_flowline.geometry = crudeoil_line.geometry  # Update to the crude oil line's geometry
        for col in crudeoil_line.index:
            updated_flowline[col] = crudeoil_line[col]
        matched_flowlines.append(updated_flowline)

# Convert the list of matched flowlines to a GeoDataFrame
matched_flowlines_gdf = gpd.GeoDataFrame(matched_flowlines, columns=flowlines_gdf.columns.union(clean_crudeoil_gdf.columns), crs=flowlines_gdf.crs)
# Out:
# Immediate company match found for flowline at index 0 without buffering.
# Immediate company match found for flowline at index 1 without buffering.
# Company match found for flowline at index 2 with buffer distance of 7.0 meters.
# Company match found for flowline at index 3 with buffer distance of 3.5 meters.
# Company match found for flowline at index 4 with buffer distance of 6.5 meters.
# Immediate company match found for flowline at index 5 without buffering.
# Company match found for flowline at index 6 with buffer distance of 6.5 meters.
# Immediate company match found for flowline at index 7 without buffering.
# Company match found for flowline at index 8 with buffer distance of 0.5 meters.
# No company match found for flowline at index 9 even after expanding buffer to 25 meters.
# No company match found for flowline at index 10 even after expanding buffer to 25 meters.
# No company match found for flowline at index 11 even after expanding buffer to 25 meters.
# No company match found for flowline at index 12 even after expanding buffer to 25 meters.
# No company match found for flowline at index 13 even after expanding buffer to 25 meters.
# No company match found for flowline at index 14 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 15 without buffering.
# Immediate company match found for flowline at index 16 without buffering.
# Immediate company match found for flowline at index 17 without buffering.
# Company match found for flowline at index 18 with buffer distance of 1.0 meters.
# Immediate company match found for flowline at index 19 without buffering.
# Immediate company match found for flowline at index 20 without buffering.
# Immediate company match found for flowline at index 21 without buffering.
# Immediate company match found for flowline at index 22 without buffering.
# Immediate company match found for flowline at index 23 without buffering.
# Immediate company match found for flowline at index 24 without buffering.
# Immediate company match found for flowline at index 25 without buffering.
# Immediate company match found for flowline at index 26 without buffering.
# Immediate company match found for flowline at index 27 without buffering.
# Immediate company match found for flowline at index 28 without buffering.
# Company match found for flowline at index 29 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 30 without buffering.
# Immediate company match found for flowline at index 31 without buffering.
# Immediate company match found for flowline at index 32 without buffering.
# Immediate company match found for flowline at index 33 without buffering.
# Company match found for flowline at index 34 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 35 without buffering.
# Immediate company match found for flowline at index 36 without buffering.
# Immediate company match found for flowline at index 37 without buffering.
# Immediate company match found for flowline at index 38 without buffering.
# Immediate company match found for flowline at index 39 without buffering.
# Immediate company match found for flowline at index 40 without buffering.
# Immediate company match found for flowline at index 41 without buffering.
# Immediate company match found for flowline at index 42 without buffering.
# Immediate company match found for flowline at index 43 without buffering.
# Immediate company match found for flowline at index 44 without buffering.
# Company match found for flowline at index 45 with buffer distance of 0.5 meters.
# Company match found for flowline at index 46 with buffer distance of 1.0 meters.
# Immediate company match found for flowline at index 47 without buffering.
# Immediate company match found for flowline at index 48 without buffering.
# Immediate company match found for flowline at index 49 without buffering.
# Immediate company match found for flowline at index 50 without buffering.
# Immediate company match found for flowline at index 51 without buffering.
# Immediate company match found for flowline at index 52 without buffering.
# Immediate company match found for flowline at index 53 without buffering.
# Immediate company match found for flowline at index 54 without buffering.
# Immediate company match found for flowline at index 55 without buffering.
# Company match found for flowline at index 56 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 57 without buffering.
# Immediate company match found for flowline at index 58 without buffering.
# Immediate company match found for flowline at index 59 without buffering.
# Immediate company match found for flowline at index 60 without buffering.
# Immediate company match found for flowline at index 61 without buffering.
# Company match found for flowline at index 62 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 63 without buffering.
# Immediate company match found for flowline at index 64 without buffering.
# Immediate company match found for flowline at index 65 without buffering.
# Immediate company match found for flowline at index 66 without buffering.
# Immediate company match found for flowline at index 67 without buffering.
# Immediate company match found for flowline at index 68 without buffering.
# Immediate company match found for flowline at index 69 without buffering.
# Immediate company match found for flowline at index 70 without buffering.
# Company match found for flowline at index 71 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 72 without buffering.
# Company match found for flowline at index 73 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 74 without buffering.
# Immediate company match found for flowline at index 75 without buffering.
# Immediate company match found for flowline at index 76 without buffering.
# Immediate company match found for flowline at index 77 without buffering.
# Immediate company match found for flowline at index 78 without buffering.
# Immediate company match found for flowline at index 79 without buffering.
# Immediate company match found for flowline at index 80 without buffering.
# Immediate company match found for flowline at index 81 without buffering.
# Immediate company match found for flowline at index 82 without buffering.
# Immediate company match found for flowline at index 83 without buffering.
# Immediate company match found for flowline at index 84 without buffering.
# Immediate company match found for flowline at index 85 without buffering.
# Immediate company match found for flowline at index 86 without buffering.
# Immediate company match found for flowline at index 87 without buffering.
# Immediate company match found for flowline at index 88 without buffering.
# Immediate company match found for flowline at index 89 without buffering.
# Immediate company match found for flowline at index 90 without buffering.
# Immediate company match found for flowline at index 91 without buffering.
# No company match found for flowline at index 92 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 93 without buffering.
# Company match found for flowline at index 94 with buffer distance of 0.5 meters.
# Company match found for flowline at index 95 with buffer distance of 1.0 meters.
# Immediate company match found for flowline at index 96 without buffering.
# Immediate company match found for flowline at index 97 without buffering.
# Immediate company match found for flowline at index 98 without buffering.
# Company match found for flowline at index 99 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 100 without buffering.
# Immediate company match found for flowline at index 101 without buffering.
# Immediate company match found for flowline at index 102 without buffering.
# Immediate company match found for flowline at index 103 without buffering.
# Immediate company match found for flowline at index 104 without buffering.
# No company match found for flowline at index 105 even after expanding buffer to 25 meters.
# No company match found for flowline at index 106 even after expanding buffer to 25 meters.
# No company match found for flowline at index 107 even after expanding buffer to 25 meters.
# No company match found for flowline at index 108 even after expanding buffer to 25 meters.
# No company match found for flowline at index 109 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 110 without buffering.
# Immediate company match found for flowline at index 111 without buffering.
# Immediate company match found for flowline at index 112 without buffering.
# Immediate company match found for flowline at index 113 without buffering.
# Immediate company match found for flowline at index 114 without buffering.
# Immediate company match found for flowline at index 115 without buffering.
# Immediate company match found for flowline at index 116 without buffering.
# Immediate company match found for flowline at index 117 without buffering.
# Immediate company match found for flowline at index 118 without buffering.
# Immediate company match found for flowline at index 119 without buffering.
# Immediate company match found for flowline at index 120 without buffering.
# Immediate company match found for flowline at index 121 without buffering.
# Immediate company match found for flowline at index 122 without buffering.
# Immediate company match found for flowline at index 123 without buffering.
# Immediate company match found for flowline at index 124 without buffering.
# Immediate company match found for flowline at index 125 without buffering.
# Immediate company match found for flowline at index 126 without buffering.
# Immediate company match found for flowline at index 127 without buffering.
# Immediate company match found for flowline at index 128 without buffering.
# Immediate company match found for flowline at index 129 without buffering.
# Immediate company match found for flowline at index 130 without buffering.
# Immediate company match found for flowline at index 131 without buffering.
# Immediate company match found for flowline at index 132 without buffering.
# Immediate company match found for flowline at index 133 without buffering.
# Immediate company match found for flowline at index 134 without buffering.
# Company match found for flowline at index 135 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 136 without buffering.
# Company match found for flowline at index 137 with buffer distance of 0.5 meters.
# Company match found for flowline at index 138 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 139 without buffering.
# Company match found for flowline at index 140 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 141 without buffering.
# Company match found for flowline at index 142 with buffer distance of 1.0 meters.
# Company match found for flowline at index 143 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 144 without buffering.
# Immediate company match found for flowline at index 145 without buffering.
# Company match found for flowline at index 146 with buffer distance of 1.0 meters.
# Company match found for flowline at index 147 with buffer distance of 1.0 meters.
# Immediate company match found for flowline at index 148 without buffering.
# No company match found for flowline at index 149 even after expanding buffer to 25 meters.
# No company match found for flowline at index 150 even after expanding buffer to 25 meters.
# No company match found for flowline at index 151 even after expanding buffer to 25 meters.
# No company match found for flowline at index 152 even after expanding buffer to 25 meters.
# No company match found for flowline at index 153 even after expanding buffer to 25 meters.
# No company match found for flowline at index 154 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 155 without buffering.
# Immediate company match found for flowline at index 156 without buffering.
# Immediate company match found for flowline at index 157 without buffering.
# Immediate company match found for flowline at index 158 without buffering.
# Immediate company match found for flowline at index 159 without buffering.
# Immediate company match found for flowline at index 160 without buffering.
# Immediate company match found for flowline at index 161 without buffering.
# Immediate company match found for flowline at index 162 without buffering.
# Immediate company match found for flowline at index 163 without buffering.
# Immediate company match found for flowline at index 164 without buffering.
# Immediate company match found for flowline at index 165 without buffering.
# Immediate company match found for flowline at index 166 without buffering.
# Immediate company match found for flowline at index 167 without buffering.
# Company match found for flowline at index 168 with buffer distance of 1.0 meters.
# Immediate company match found for flowline at index 169 without buffering.
# Immediate company match found for flowline at index 170 without buffering.
# Immediate company match found for flowline at index 171 without buffering.
# Company match found for flowline at index 172 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 173 without buffering.
# Company match found for flowline at index 174 with buffer distance of 1.0 meters.
# Immediate company match found for flowline at index 175 without buffering.
# Immediate company match found for flowline at index 176 without buffering.
# Company match found for flowline at index 177 with buffer distance of 1.0 meters.
# No company match found for flowline at index 178 even after expanding buffer to 25 meters.
# No company match found for flowline at index 179 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 180 without buffering.
# Immediate company match found for flowline at index 181 without buffering.
# Immediate company match found for flowline at index 182 without buffering.
# Immediate company match found for flowline at index 183 without buffering.
# Immediate company match found for flowline at index 184 without buffering.
# Immediate company match found for flowline at index 185 without buffering.
# Immediate company match found for flowline at index 186 without buffering.
# Immediate company match found for flowline at index 187 without buffering.
# Immediate company match found for flowline at index 188 without buffering.
# Immediate company match found for flowline at index 189 without buffering.
# Immediate company match found for flowline at index 190 without buffering.
# Immediate company match found for flowline at index 191 without buffering.
# Immediate company match found for flowline at index 192 without buffering.
# Immediate company match found for flowline at index 193 without buffering.
# Immediate company match found for flowline at index 194 without buffering.
# Immediate company match found for flowline at index 195 without buffering.
# Immediate company match found for flowline at index 196 without buffering.
# Immediate company match found for flowline at index 197 without buffering.
# Immediate company match found for flowline at index 198 without buffering.
# Immediate company match found for flowline at index 199 without buffering.
# Immediate company match found for flowline at index 200 without buffering.
# Immediate company match found for flowline at index 201 without buffering.
# Immediate company match found for flowline at index 202 without buffering.
# Immediate company match found for flowline at index 203 without buffering.
# Immediate company match found for flowline at index 204 without buffering.
# Immediate company match found for flowline at index 205 without buffering.
# Company match found for flowline at index 206 with buffer distance of 2.0 meters.
# Immediate company match found for flowline at index 207 without buffering.
# Company match found for flowline at index 208 with buffer distance of 9.5 meters.
# Immediate company match found for flowline at index 209 without buffering.
# Company match found for flowline at index 210 with buffer distance of 2.0 meters.
# Company match found for flowline at index 211 with buffer distance of 2.0 meters.
# Company match found for flowline at index 212 with buffer distance of 11.0 meters.
# No company match found for flowline at index 213 even after expanding buffer to 25 meters.
# No company match found for flowline at index 214 even after expanding buffer to 25 meters.
# No company match found for flowline at index 215 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 216 without buffering.
# Company match found for flowline at index 217 with buffer distance of 1.0 meters.
# Immediate company match found for flowline at index 218 without buffering.
# Immediate company match found for flowline at index 219 without buffering.
# Immediate company match found for flowline at index 220 without buffering.
# No company match found for flowline at index 221 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 222 without buffering.
# Immediate company match found for flowline at index 223 without buffering.
# Immediate company match found for flowline at index 224 without buffering.
# Company match found for flowline at index 225 with buffer distance of 1.0 meters.
# Company match found for flowline at index 226 with buffer distance of 0.5 meters.
# Company match found for flowline at index 227 with buffer distance of 0.5 meters.
# Company match found for flowline at index 228 with buffer distance of 1.5 meters.
# Immediate company match found for flowline at index 229 without buffering.
# Immediate company match found for flowline at index 230 without buffering.
# Immediate company match found for flowline at index 231 without buffering.
# Immediate company match found for flowline at index 232 without buffering.
# Immediate company match found for flowline at index 233 without buffering.
# Immediate company match found for flowline at index 234 without buffering.
# Immediate company match found for flowline at index 235 without buffering.
# Immediate company match found for flowline at index 236 without buffering.
# Immediate company match found for flowline at index 237 without buffering.
# Immediate company match found for flowline at index 238 without buffering.
# Immediate company match found for flowline at index 239 without buffering.
# Immediate company match found for flowline at index 240 without buffering.
# Immediate company match found for flowline at index 241 without buffering.
# Immediate company match found for flowline at index 242 without buffering.
# Immediate company match found for flowline at index 243 without buffering.
# Immediate company match found for flowline at index 244 without buffering.
# Immediate company match found for flowline at index 245 without buffering.
# Immediate company match found for flowline at index 246 without buffering.
# Immediate company match found for flowline at index 247 without buffering.
# Immediate company match found for flowline at index 248 without buffering.
# Immediate company match found for flowline at index 249 without buffering.
# Immediate company match found for flowline at index 250 without buffering.
# Immediate company match found for flowline at index 251 without buffering.
# Immediate company match found for flowline at index 252 without buffering.
# Immediate company match found for flowline at index 253 without buffering.
# Immediate company match found for flowline at index 254 without buffering.
# Immediate company match found for flowline at index 255 without buffering.
# Immediate company match found for flowline at index 256 without buffering.
# Immediate company match found for flowline at index 257 without buffering.
# Immediate company match found for flowline at index 258 without buffering.
# Immediate company match found for flowline at index 259 without buffering.
# Immediate company match found for flowline at index 260 without buffering.
# Immediate company match found for flowline at index 261 without buffering.
# Immediate company match found for flowline at index 262 without buffering.
# Company match found for flowline at index 263 with buffer distance of 0.5 meters.
# Company match found for flowline at index 264 with buffer distance of 0.5 meters.
# Company match found for flowline at index 265 with buffer distance of 3.0 meters.
# Immediate company match found for flowline at index 266 without buffering.
# Immediate company match found for flowline at index 267 without buffering.
# Immediate company match found for flowline at index 268 without buffering.
# Immediate company match found for flowline at index 269 without buffering.
# Immediate company match found for flowline at index 270 without buffering.
# Immediate company match found for flowline at index 271 without buffering.
# Immediate company match found for flowline at index 272 without buffering.
# Immediate company match found for flowline at index 273 without buffering.
# Immediate company match found for flowline at index 274 without buffering.
# Immediate company match found for flowline at index 275 without buffering.
# Immediate company match found for flowline at index 276 without buffering.
# Immediate company match found for flowline at index 277 without buffering.
# Immediate company match found for flowline at index 278 without buffering.
# Immediate company match found for flowline at index 279 without buffering.
# Immediate company match found for flowline at index 280 without buffering.
# Company match found for flowline at index 281 with buffer distance of 1.0 meters.
# Immediate company match found for flowline at index 282 without buffering.
# Immediate company match found for flowline at index 283 without buffering.
# No company match found for flowline at index 284 even after expanding buffer to 25 meters.
# No company match found for flowline at index 285 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 286 without buffering.
# Immediate company match found for flowline at index 287 without buffering.
# Immediate company match found for flowline at index 288 without buffering.
# Immediate company match found for flowline at index 289 without buffering.
# Company match found for flowline at index 290 with buffer distance of 0.5 meters.
# No company match found for flowline at index 291 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 292 without buffering.
# Immediate company match found for flowline at index 293 without buffering.
# Immediate company match found for flowline at index 294 without buffering.
# Immediate company match found for flowline at index 295 without buffering.
# Company match found for flowline at index 296 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 297 without buffering.
# Immediate company match found for flowline at index 298 without buffering.
# Immediate company match found for flowline at index 299 without buffering.
# Immediate company match found for flowline at index 300 without buffering.
# Immediate company match found for flowline at index 301 without buffering.
# Immediate company match found for flowline at index 302 without buffering.
# Immediate company match found for flowline at index 303 without buffering.
# Immediate company match found for flowline at index 304 without buffering.
# Immediate company match found for flowline at index 305 without buffering.
# Immediate company match found for flowline at index 306 without buffering.
# Immediate company match found for flowline at index 307 without buffering.
# Immediate company match found for flowline at index 308 without buffering.
# No company match found for flowline at index 309 even after expanding buffer to 25 meters.
# No company match found for flowline at index 310 even after expanding buffer to 25 meters.
# No company match found for flowline at index 311 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 312 without buffering.
# Immediate company match found for flowline at index 313 without buffering.
# Immediate company match found for flowline at index 314 without buffering.
# Immediate company match found for flowline at index 315 without buffering.
# Immediate company match found for flowline at index 316 without buffering.
# Immediate company match found for flowline at index 317 without buffering.
# Immediate company match found for flowline at index 318 without buffering.
# Immediate company match found for flowline at index 319 without buffering.
# Immediate company match found for flowline at index 320 without buffering.
# Immediate company match found for flowline at index 321 without buffering.
# Immediate company match found for flowline at index 322 without buffering.
# Immediate company match found for flowline at index 323 without buffering.
# Immediate company match found for flowline at index 324 without buffering.
# No company match found for flowline at index 325 even after expanding buffer to 25 meters.
# No company match found for flowline at index 326 even after expanding buffer to 25 meters.
# No company match found for flowline at index 327 even after expanding buffer to 25 meters.
# No company match found for flowline at index 328 even after expanding buffer to 25 meters.
# No company match found for flowline at index 329 even after expanding buffer to 25 meters.
# No company match found for flowline at index 330 even after expanding buffer to 25 meters.
# No company match found for flowline at index 331 even after expanding buffer to 25 meters.
# No company match found for flowline at index 332 even after expanding buffer to 25 meters.
# No company match found for flowline at index 333 even after expanding buffer to 25 meters.
# No company match found for flowline at index 334 even after expanding buffer to 25 meters.
# No company match found for flowline at index 335 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 336 without buffering.
# Immediate company match found for flowline at index 337 without buffering.
# Company match found for flowline at index 338 with buffer distance of 0.5 meters.
# Company match found for flowline at index 339 with buffer distance of 0.5 meters.
# Company match found for flowline at index 340 with buffer distance of 0.5 meters.
# Company match found for flowline at index 341 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 342 without buffering.
# Immediate company match found for flowline at index 343 without buffering.
# Immediate company match found for flowline at index 344 without buffering.
# Company match found for flowline at index 345 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 346 without buffering.
# Immediate company match found for flowline at index 347 without buffering.
# Immediate company match found for flowline at index 348 without buffering.
# Immediate company match found for flowline at index 349 without buffering.
# Immediate company match found for flowline at index 350 without buffering.
# Immediate company match found for flowline at index 351 without buffering.
# Immediate company match found for flowline at index 352 without buffering.
# Company match found for flowline at index 353 with buffer distance of 3.0 meters.
# Company match found for flowline at index 354 with buffer distance of 1.0 meters.
# Company match found for flowline at index 355 with buffer distance of 0.5 meters.
# Company match found for flowline at index 356 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 357 without buffering.
# Immediate company match found for flowline at index 358 without buffering.
# Immediate company match found for flowline at index 359 without buffering.
# Immediate company match found for flowline at index 360 without buffering.
# Immediate company match found for flowline at index 361 without buffering.
# Immediate company match found for flowline at index 362 without buffering.
# Immediate company match found for flowline at index 363 without buffering.
# Immediate company match found for flowline at index 364 without buffering.
# Immediate company match found for flowline at index 365 without buffering.
# Immediate company match found for flowline at index 366 without buffering.
# Immediate company match found for flowline at index 367 without buffering.
# Company match found for flowline at index 368 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 369 without buffering.
# Immediate company match found for flowline at index 370 without buffering.
# Immediate company match found for flowline at index 371 without buffering.
# Immediate company match found for flowline at index 372 without buffering.
# Immediate company match found for flowline at index 373 without buffering.
# Immediate company match found for flowline at index 374 without buffering.
# Immediate company match found for flowline at index 375 without buffering.
# Immediate company match found for flowline at index 376 without buffering.
# Immediate company match found for flowline at index 377 without buffering.
# Immediate company match found for flowline at index 378 without buffering.
# Immediate company match found for flowline at index 379 without buffering.
# Immediate company match found for flowline at index 380 without buffering.
# Immediate company match found for flowline at index 381 without buffering.
# Immediate company match found for flowline at index 382 without buffering.
# Immediate company match found for flowline at index 383 without buffering.
# Immediate company match found for flowline at index 384 without buffering.
# Immediate company match found for flowline at index 385 without buffering.
# Immediate company match found for flowline at index 386 without buffering.
# Immediate company match found for flowline at index 387 without buffering.
# Immediate company match found for flowline at index 388 without buffering.
# Immediate company match found for flowline at index 389 without buffering.
# Immediate company match found for flowline at index 390 without buffering.
# Immediate company match found for flowline at index 391 without buffering.
# Immediate company match found for flowline at index 392 without buffering.
# Immediate company match found for flowline at index 393 without buffering.
# Immediate company match found for flowline at index 394 without buffering.
# Immediate company match found for flowline at index 395 without buffering.
# Immediate company match found for flowline at index 396 without buffering.
# Immediate company match found for flowline at index 397 without buffering.
# No company match found for flowline at index 398 even after expanding buffer to 25 meters.
# No company match found for flowline at index 399 even after expanding buffer to 25 meters.
# No company match found for flowline at index 400 even after expanding buffer to 25 meters.
# No company match found for flowline at index 401 even after expanding buffer to 25 meters.
# No company match found for flowline at index 402 even after expanding buffer to 25 meters.
# No company match found for flowline at index 403 even after expanding buffer to 25 meters.
# No company match found for flowline at index 404 even after expanding buffer to 25 meters.
# Company match found for flowline at index 405 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 406 without buffering.
# Company match found for flowline at index 407 with buffer distance of 8.0 meters.
# Immediate company match found for flowline at index 408 without buffering.
# Immediate company match found for flowline at index 409 without buffering.
# No company match found for flowline at index 410 even after expanding buffer to 25 meters.
# No company match found for flowline at index 411 even after expanding buffer to 25 meters.
# No company match found for flowline at index 412 even after expanding buffer to 25 meters.
# No company match found for flowline at index 413 even after expanding buffer to 25 meters.
# No company match found for flowline at index 414 even after expanding buffer to 25 meters.
# No company match found for flowline at index 415 even after expanding buffer to 25 meters.
# No company match found for flowline at index 416 even after expanding buffer to 25 meters.
# No company match found for flowline at index 417 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 418 without buffering.
# No company match found for flowline at index 419 even after expanding buffer to 25 meters.
# No company match found for flowline at index 420 even after expanding buffer to 25 meters.
# No company match found for flowline at index 421 even after expanding buffer to 25 meters.
# No company match found for flowline at index 422 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 423 without buffering.
# Immediate company match found for flowline at index 424 without buffering.
# Immediate company match found for flowline at index 425 without buffering.
# Immediate company match found for flowline at index 426 without buffering.
# Immediate company match found for flowline at index 427 without buffering.
# Immediate company match found for flowline at index 428 without buffering.
# Immediate company match found for flowline at index 429 without buffering.
# Company match found for flowline at index 430 with buffer distance of 1.0 meters.
# Immediate company match found for flowline at index 431 without buffering.
# Immediate company match found for flowline at index 432 without buffering.
# Immediate company match found for flowline at index 433 without buffering.
# Immediate company match found for flowline at index 434 without buffering.
# Immediate company match found for flowline at index 435 without buffering.
# Immediate company match found for flowline at index 436 without buffering.
# Immediate company match found for flowline at index 437 without buffering.
# Company match found for flowline at index 438 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 439 without buffering.
# Immediate company match found for flowline at index 440 without buffering.
# Immediate company match found for flowline at index 441 without buffering.
# Immediate company match found for flowline at index 442 without buffering.
# Immediate company match found for flowline at index 443 without buffering.
# Immediate company match found for flowline at index 444 without buffering.
# Immediate company match found for flowline at index 445 without buffering.
# Immediate company match found for flowline at index 446 without buffering.
# Immediate company match found for flowline at index 447 without buffering.
# Immediate company match found for flowline at index 448 without buffering.
# Immediate company match found for flowline at index 449 without buffering.
# Immediate company match found for flowline at index 450 without buffering.
# Immediate company match found for flowline at index 451 without buffering.
# Immediate company match found for flowline at index 452 without buffering.
# Immediate company match found for flowline at index 453 without buffering.
# Immediate company match found for flowline at index 454 without buffering.
# Immediate company match found for flowline at index 455 without buffering.
# Immediate company match found for flowline at index 456 without buffering.
# Immediate company match found for flowline at index 457 without buffering.
# Immediate company match found for flowline at index 458 without buffering.
# Immediate company match found for flowline at index 459 without buffering.
# Immediate company match found for flowline at index 460 without buffering.
# Immediate company match found for flowline at index 461 without buffering.
# Immediate company match found for flowline at index 462 without buffering.
# Immediate company match found for flowline at index 463 without buffering.
# Company match found for flowline at index 464 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 465 without buffering.
# Immediate company match found for flowline at index 466 without buffering.
# Immediate company match found for flowline at index 467 without buffering.
# Immediate company match found for flowline at index 468 without buffering.
# Immediate company match found for flowline at index 469 without buffering.
# Immediate company match found for flowline at index 470 without buffering.
# Immediate company match found for flowline at index 471 without buffering.
# Immediate company match found for flowline at index 472 without buffering.
# Immediate company match found for flowline at index 473 without buffering.
# Immediate company match found for flowline at index 474 without buffering.
# Immediate company match found for flowline at index 475 without buffering.
# Immediate company match found for flowline at index 476 without buffering.
# Immediate company match found for flowline at index 477 without buffering.
# Immediate company match found for flowline at index 478 without buffering.
# Immediate company match found for flowline at index 479 without buffering.
# Immediate company match found for flowline at index 480 without buffering.
# Immediate company match found for flowline at index 481 without buffering.
# Immediate company match found for flowline at index 482 without buffering.
# Immediate company match found for flowline at index 483 without buffering.
# Immediate company match found for flowline at index 484 without buffering.
# Immediate company match found for flowline at index 485 without buffering.
# Immediate company match found for flowline at index 486 without buffering.
# Immediate company match found for flowline at index 487 without buffering.
# Immediate company match found for flowline at index 488 without buffering.
# Immediate company match found for flowline at index 489 without buffering.
# Immediate company match found for flowline at index 490 without buffering.
# Company match found for flowline at index 491 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 492 without buffering.
# Immediate company match found for flowline at index 493 without buffering.
# No company match found for flowline at index 494 even after expanding buffer to 25 meters.
# No company match found for flowline at index 495 even after expanding buffer to 25 meters.
# No company match found for flowline at index 496 even after expanding buffer to 25 meters.
# No company match found for flowline at index 497 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 498 without buffering.
# Immediate company match found for flowline at index 499 without buffering.
# Immediate company match found for flowline at index 500 without buffering.
# Immediate company match found for flowline at index 501 without buffering.
# Immediate company match found for flowline at index 502 without buffering.
# Immediate company match found for flowline at index 503 without buffering.
# Immediate company match found for flowline at index 504 without buffering.
# Immediate company match found for flowline at index 505 without buffering.
# Immediate company match found for flowline at index 506 without buffering.
# Immediate company match found for flowline at index 507 without buffering.
# Immediate company match found for flowline at index 508 without buffering.
# Immediate company match found for flowline at index 509 without buffering.
# Immediate company match found for flowline at index 510 without buffering.
# Immediate company match found for flowline at index 511 without buffering.
# Immediate company match found for flowline at index 512 without buffering.
# Immediate company match found for flowline at index 513 without buffering.
# Immediate company match found for flowline at index 514 without buffering.
# Immediate company match found for flowline at index 515 without buffering.
# Immediate company match found for flowline at index 516 without buffering.
# Immediate company match found for flowline at index 517 without buffering.
# Immediate company match found for flowline at index 518 without buffering.
# Immediate company match found for flowline at index 519 without buffering.
# Immediate company match found for flowline at index 520 without buffering.
# Immediate company match found for flowline at index 521 without buffering.
# Immediate company match found for flowline at index 522 without buffering.
# Company match found for flowline at index 523 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 524 without buffering.
# Company match found for flowline at index 525 with buffer distance of 1.0 meters.
# Company match found for flowline at index 526 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 527 without buffering.
# Immediate company match found for flowline at index 528 without buffering.
# Immediate company match found for flowline at index 529 without buffering.
# Immediate company match found for flowline at index 530 without buffering.
# Immediate company match found for flowline at index 531 without buffering.
# Immediate company match found for flowline at index 532 without buffering.
# Immediate company match found for flowline at index 533 without buffering.
# Immediate company match found for flowline at index 534 without buffering.
# Immediate company match found for flowline at index 535 without buffering.
# Immediate company match found for flowline at index 536 without buffering.
# Immediate company match found for flowline at index 537 without buffering.
# Company match found for flowline at index 538 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 539 without buffering.
# Immediate company match found for flowline at index 540 without buffering.
# Immediate company match found for flowline at index 541 without buffering.
# Immediate company match found for flowline at index 542 without buffering.
# Immediate company match found for flowline at index 543 without buffering.
# Company match found for flowline at index 544 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 545 without buffering.
# Immediate company match found for flowline at index 546 without buffering.
# Immediate company match found for flowline at index 547 without buffering.
# Immediate company match found for flowline at index 548 without buffering.
# Immediate company match found for flowline at index 549 without buffering.
# Immediate company match found for flowline at index 550 without buffering.
# Immediate company match found for flowline at index 551 without buffering.
# Immediate company match found for flowline at index 552 without buffering.
# Immediate company match found for flowline at index 553 without buffering.
# Immediate company match found for flowline at index 554 without buffering.
# Immediate company match found for flowline at index 555 without buffering.
# Immediate company match found for flowline at index 556 without buffering.
# Immediate company match found for flowline at index 557 without buffering.
# Immediate company match found for flowline at index 558 without buffering.
# Immediate company match found for flowline at index 559 without buffering.
# Immediate company match found for flowline at index 560 without buffering.
# Immediate company match found for flowline at index 561 without buffering.
# Immediate company match found for flowline at index 562 without buffering.
# Immediate company match found for flowline at index 563 without buffering.
# Immediate company match found for flowline at index 564 without buffering.
# Immediate company match found for flowline at index 565 without buffering.
# Immediate company match found for flowline at index 566 without buffering.
# Immediate company match found for flowline at index 567 without buffering.
# Immediate company match found for flowline at index 568 without buffering.
# Immediate company match found for flowline at index 569 without buffering.
# Company match found for flowline at index 570 with buffer distance of 1.0 meters.
# Immediate company match found for flowline at index 571 without buffering.
# Immediate company match found for flowline at index 572 without buffering.
# Company match found for flowline at index 573 with buffer distance of 1.5 meters.
# Immediate company match found for flowline at index 574 without buffering.
# Immediate company match found for flowline at index 575 without buffering.
# Company match found for flowline at index 576 with buffer distance of 1.0 meters.
# Company match found for flowline at index 577 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 578 without buffering.
# Immediate company match found for flowline at index 579 without buffering.
# Immediate company match found for flowline at index 580 without buffering.
# Immediate company match found for flowline at index 581 without buffering.
# Immediate company match found for flowline at index 582 without buffering.
# Immediate company match found for flowline at index 583 without buffering.
# Immediate company match found for flowline at index 584 without buffering.
# Immediate company match found for flowline at index 585 without buffering.
# Company match found for flowline at index 586 with buffer distance of 0.5 meters.
# Company match found for flowline at index 587 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 588 without buffering.
# Immediate company match found for flowline at index 589 without buffering.
# Immediate company match found for flowline at index 590 without buffering.
# Immediate company match found for flowline at index 591 without buffering.
# Immediate company match found for flowline at index 592 without buffering.
# Immediate company match found for flowline at index 593 without buffering.
# Immediate company match found for flowline at index 594 without buffering.
# Immediate company match found for flowline at index 595 without buffering.
# Immediate company match found for flowline at index 596 without buffering.
# Immediate company match found for flowline at index 597 without buffering.
# Immediate company match found for flowline at index 598 without buffering.
# Immediate company match found for flowline at index 599 without buffering.
# Immediate company match found for flowline at index 600 without buffering.
# Immediate company match found for flowline at index 601 without buffering.
# Immediate company match found for flowline at index 602 without buffering.
# Immediate company match found for flowline at index 603 without buffering.
# Immediate company match found for flowline at index 604 without buffering.
# Immediate company match found for flowline at index 605 without buffering.
# Immediate company match found for flowline at index 606 without buffering.
# Immediate company match found for flowline at index 607 without buffering.
# Immediate company match found for flowline at index 608 without buffering.
# Immediate company match found for flowline at index 609 without buffering.
# Immediate company match found for flowline at index 610 without buffering.
# Immediate company match found for flowline at index 611 without buffering.
# Company match found for flowline at index 612 with buffer distance of 2.0 meters.
# Company match found for flowline at index 613 with buffer distance of 1.5 meters.
# Immediate company match found for flowline at index 614 without buffering.
# Company match found for flowline at index 615 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 616 without buffering.
# Company match found for flowline at index 617 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 618 without buffering.
# Immediate company match found for flowline at index 619 without buffering.
# ...
# No company match found for flowline at index 21060 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21061 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21062 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21063 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 21064 without buffering.
# Immediate company match found for flowline at index 21065 without buffering.
# No company match found for flowline at index 21066 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21067 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21068 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21069 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 21070 without buffering.
# Immediate company match found for flowline at index 21071 without buffering.
# Immediate company match found for flowline at index 21072 without buffering.
# Immediate company match found for flowline at index 21073 without buffering.
# Immediate company match found for flowline at index 21074 without buffering.
# Immediate company match found for flowline at index 21075 without buffering.
# Immediate company match found for flowline at index 21076 without buffering.
# Immediate company match found for flowline at index 21077 without buffering.
# Immediate company match found for flowline at index 21078 without buffering.
# Immediate company match found for flowline at index 21079 without buffering.
# No company match found for flowline at index 21080 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21081 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21082 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21083 even after expanding buffer to 25 meters.
# Company match found for flowline at index 21084 with buffer distance of 1.0 meters.
# No company match found for flowline at index 21085 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21086 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21087 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21088 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 21089 without buffering.
# Company match found for flowline at index 21090 with buffer distance of 7.5 meters.
# Company match found for flowline at index 21091 with buffer distance of 9.0 meters.
# No company match found for flowline at index 21092 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21093 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21094 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21095 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21096 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21097 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21098 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21099 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21100 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21101 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21102 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21103 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21104 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21105 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 21106 without buffering.
# No company match found for flowline at index 21107 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21108 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 21109 without buffering.
# Immediate company match found for flowline at index 21110 without buffering.
# Immediate company match found for flowline at index 21111 without buffering.
# Immediate company match found for flowline at index 21112 without buffering.
# Immediate company match found for flowline at index 21113 without buffering.
# Immediate company match found for flowline at index 21114 without buffering.
# No company match found for flowline at index 21115 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21116 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21117 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21118 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 21119 without buffering.
# Immediate company match found for flowline at index 21120 without buffering.
# Immediate company match found for flowline at index 21121 without buffering.
# Immediate company match found for flowline at index 21122 without buffering.
# Company match found for flowline at index 21123 with buffer distance of 0.5 meters.
# No company match found for flowline at index 21124 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21125 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21126 even after expanding buffer to 25 meters.
# Company match found for flowline at index 21127 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 21128 without buffering.
# Company match found for flowline at index 21129 with buffer distance of 0.5 meters.
# Company match found for flowline at index 21130 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 21131 without buffering.
# Immediate company match found for flowline at index 21132 without buffering.
# Company match found for flowline at index 21133 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 21134 without buffering.
# Immediate company match found for flowline at index 21135 without buffering.
# Company match found for flowline at index 21136 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 21137 without buffering.
# Company match found for flowline at index 21138 with buffer distance of 0.5 meters.
# No company match found for flowline at index 21139 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21140 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21141 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21142 even after expanding buffer to 25 meters.
# Company match found for flowline at index 21143 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 21144 without buffering.
# Immediate company match found for flowline at index 21145 without buffering.
# Immediate company match found for flowline at index 21146 without buffering.
# Company match found for flowline at index 21147 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 21148 without buffering.
# Immediate company match found for flowline at index 21149 without buffering.
# Immediate company match found for flowline at index 21150 without buffering.
# Immediate company match found for flowline at index 21151 without buffering.
# Immediate company match found for flowline at index 21152 without buffering.
# Immediate company match found for flowline at index 21153 without buffering.
# Immediate company match found for flowline at index 21154 without buffering.
# Immediate company match found for flowline at index 21155 without buffering.
# Immediate company match found for flowline at index 21156 without buffering.
# Immediate company match found for flowline at index 21157 without buffering.
# Immediate company match found for flowline at index 21158 without buffering.
# Immediate company match found for flowline at index 21159 without buffering.
# Company match found for flowline at index 21160 with buffer distance of 1.5 meters.
# Company match found for flowline at index 21161 with buffer distance of 1.5 meters.
# No company match found for flowline at index 21162 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21163 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21164 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21165 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21166 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21167 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21168 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21169 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21170 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21171 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21172 even after expanding buffer to 25 meters.
# No company match found for flowline at index 21173 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 21174 without buffering.
# Immediate company match found for flowline at index 21175 without buffering.
# Immediate company match found for flowline at index 21176 without buffering.
# Immediate company match found for flowline at index 21177 without buffering.
# Company match found for flowline at index 21178 with buffer distance of 2.5 meters.
# Immediate company match found for flowline at index 21179 without buffering.
# Immediate company match found for flowline at index 21180 without buffering.
# Immediate company match found for flowline at index 21181 without buffering.
# Immediate company match found for flowline at index 21182 without buffering.
# Company match found for flowline at index 21183 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 21184 without buffering.
# Immediate company match found for flowline at index 21185 without buffering.
# Company match found for flowline at index 21186 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 21187 without buffering.
# Immediate company match found for flowline at index 21188 without buffering.
# Immediate company match found for flowline at index 21189 without buffering.
# Immediate company match found for flowline at index 21190 without buffering.
# Immediate company match found for flowline at index 21191 without buffering.
# Company match found for flowline at index 21192 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 21193 without buffering.
# Immediate company match found for flowline at index 21194 without buffering.
# Immediate company match found for flowline at index 21195 without buffering.
# Immediate company match found for flowline at index 21196 without buffering.
# Immediate company match found for flowline at index 21197 without buffering.
# Immediate company match found for flowline at index 21198 without buffering.
# Immediate company match found for flowline at index 21199 without buffering.
# Company match found for flowline at index 21200 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 21201 without buffering.
# Immediate company match found for flowline at index 21202 without buffering.
# Immediate company match found for flowline at index 21203 without buffering.
# Immediate company match found for flowline at index 21204 without buffering.
# Immediate company match found for flowline at index 21205 without buffering.
# Immediate company match found for flowline at index 21206 without buffering.
# Immediate company match found for flowline at index 21207 without buffering.
# Immediate company match found for flowline at index 21208 without buffering.
# Immediate company match found for flowline at index 21209 without buffering.
# Immediate company match found for flowline at index 21210 without buffering.
# Company match found for flowline at index 21211 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 21212 without buffering.
# Immediate company match found for flowline at index 21213 without buffering.
# Immediate company match found for flowline at index 21214 without buffering.
# Immediate company match found for flowline at index 21215 without buffering.
# Immediate company match found for flowline at index 21216 without buffering.
# No company match found for flowline at index 21217 even after expanding buffer to 25 meters.
# Company match found for flowline at index 21218 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 21219 without buffering.
# Immediate company match found for flowline at index 21220 without buffering.
# Immediate company match found for flowline at index 21221 without buffering.
# Company match found for flowline at index 21222 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 21223 without buffering.
# Immediate company match found for flowline at index 21224 without buffering.
# Immediate company match found for flowline at index 21225 without buffering.
# Company match found for flowline at index 21226 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 21227 without buffering.
# Immediate company match found for flowline at index 21228 without buffering.
# Immediate company match found for flowline at index 21229 without buffering.
# Company match found for flowline at index 21230 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 21231 without buffering.
# No company match found for flowline at index 21232 even after expanding buffer to 25 meters.
# Immediate company match found for flowline at index 21233 without buffering.
# Immediate company match found for flowline at index 21234 without buffering.
# Immediate company match found for flowline at index 21235 without buffering.
# Immediate company match found for flowline at index 21236 without buffering.
# Company match found for flowline at index 21237 with buffer distance of 1.0 meters.
# Immediate company match found for flowline at index 21238 without buffering.
# Immediate company match found for flowline at index 21239 without buffering.
# Immediate company match found for flowline at index 21240 without buffering.
# Immediate company match found for flowline at index 21241 without buffering.
# Immediate company match found for flowline at index 21242 without buffering.
# Immediate company match found for flowline at index 21243 without buffering.
# Immediate company match found for flowline at index 21244 without buffering.
# Immediate company match found for flowline at index 21245 without buffering.
# Immediate company match found for flowline at index 21246 without buffering.
# Company match found for flowline at index 21247 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 21248 without buffering.
# Company match found for flowline at index 21249 with buffer distance of 0.5 meters.
# Immediate company match found for flowline at index 21250 without buffering.
# Immediate company match found for flowline at index 21251 without buffering.
# Immediate company match found for flowline at index 21252 without buffering.

# %%
matched_flowlines_gdf.head()
# Out:
#                                    ACTIONDESCRIPTION   BEDDINGMATERIAL  \
# 0  The flowline serving the Emerson 3-29J (05-123...  Native Materials
# 1  The flowline (12311399_FL) servicing the Emers...  Native Materials
# 2                                               None              None
# 3                                               None              None
# 4                                               None              None
#
#                                         COMPANY_NAME CONSTRUCTDATE  Diam_in  \
# 0  CRESTONE PEAK RESOURCES OPERATING LLC         ...    1983-11-09      2.0
# 1  CRESTONE PEAK RESOURCES OPERATING LLC         ...    1983-12-07      2.0
# 2  PETERSON ENERGY OPERATING INC                 ...    2006-06-05      2.0
# 3  PETERSON ENERGY OPERATING INC                 ...    2007-04-08      2.0
# 4  PETERSON ENERGY OPERATING INC                 ...    2005-05-10      2.0
#
#       ENDLAT     ENDLONG ENTIRELINEREMOVED  FLOWLINEACTION  FLOWLINEID  \
# 0  40.109444 -104.909686              None            None    470446.0
# 1  40.109441 -104.909670              True  Out of Service    470445.0
# 2  40.063138 -105.034086              None            None    466061.0
# 3  40.063142 -105.034085              None            None    466062.0
# 4  40.063132 -105.034086              None            None    466063.0
#
#                 Fluid           LOCATIONTYPE  LOCATION_ID  Length_ft  \
# 0          Multiphase  Production Facilities     470443.0    1361.28
# 1          Multiphase  Production Facilities     470443.0    1025.98
# 2  Crude Oil Emulsion  Production Facilities     318620.0     276.03
# 3  Crude Oil Emulsion  Production Facilities     318620.0     276.03
# 4  Crude Oil Emulsion  Production Facilities     318620.0     276.03
#
#    MAXOPPRESSURE      Material  OPERATOR_NUM  \
# 0          325.0  Carbon Steel         10633
# 1          250.0  Carbon Steel         10633
# 2            NaN    Fiberglass         68710
# 3            NaN    Fiberglass         68710
# 4            NaN    Fiberglass         68710
#
#                                 Operator  PIPEMATERIAL  \
# 0  CRESTONE PEAK RESOURCES OPERATING LLC  Carbon Steel
# 1  CRESTONE PEAK RESOURCES OPERATING LLC  Carbon Steel
# 2          PETERSON ENERGY OPERATING INC  Carbon Steel
# 3          PETERSON ENERGY OPERATING INC  Carbon Steel
# 4          PETERSON ENERGY OPERATING INC  Carbon Steel
#
#              RECEIVE_DATE  SHAPE_Length   STARTLAT  STARTLOCATIONID  \
# 0 2023-10-24 08:33:49.223    414.751530  40.105743              NaN
# 1 2023-10-24 08:33:49.223    312.594254  40.112203         319521.0
# 2 2023-10-24 16:00:01.117     84.099157  40.063823         305594.0
# 3 2023-10-24 16:00:01.117     84.099157  40.060063         305595.0
# 4 2023-10-24 16:00:01.117     84.099157  40.059581         332338.0
#
#     STARTLONG  Status TYPEOFFLUIDTRANS  \
# 0 -104.909860  Active       Multiphase
# 1 -104.909862  Active       Multiphase
# 2 -105.030068  Active       Multiphase
# 3 -105.034795  Active       Multiphase
# 4 -105.029331  Active       Multiphase
#
#                                             geometry
# 0  MULTILINESTRING ((507682.447 4439497.657, 5076...
# 1  MULTILINESTRING ((507681.553 4440214.644, 5076...
# 2  MULTILINESTRING ((497028.859 4434818.938, 4970...
# 3  MULTILINESTRING ((497028.859 4434818.938, 4970...
# 4  MULTILINESTRING ((497028.859 4434818.938, 4970...

# %%
matched_flowlines_gdf.shape
# Out:
# (14921, 27)

# %%
matched_flowlines_gdf.to_file("matched_flowlines.geojson", driver='GeoJSON')
